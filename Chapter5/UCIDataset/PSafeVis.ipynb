# %%
import os
import json

import pandas as pd
#df = pd.DataFrame(columns=['post', 'bound', 'index', 'label', 'pred', 'epsilon', 'p_safe_attack': 1.0, 'd_safe_attack': True, 'p_safe_bounds' , 'd_safe_bounds', 'beps', 'bdelt', 'balpha', 'iterations_attack', 'iterations_bounds', 'veri_time', 'attk_time'])
rows = []
def load(dataset, bound):
    entries = []
    path = "ExperimentalLogs/%s_%s.log"%(dataset, bound)
    with open(path) as log_file:
        for line in log_file:
            #print(json.loads(line))
            entries.append(json.loads(line))
            entry = json.loads(line)
            #entry['Dataset'] = dataset
            #entry['Bound'] = bound
            entry['Dataset'] = dataset[0:-1]
            entry['Bound'] = bound
            entry['Method'] = 'Attack'
            entry['p_safe_bounds'] = entry['p_safe_attack']
            rows.append(entry)
            entry2 = json.loads(line)
            entry2['Dataset'] = dataset[0:-1]
            entry2['Bound'] = bound
            entry2['Method'] = 'Cert'
            entry2['p_safe_attack'] = entry2['p_safe_bounds']
            rows.append(entry2)
    return entries

log_info = load("boston1", "massart")
log_info = load("concrete1", "massart")
log_info = load("yacht1", "massart")
log_info = load("powerplant1", "massart")
log_info = load("energy1", "massart")
log_info = load("kin8nm1", "massart")
log_info = load("naval1", "massart")
log_info = load("wine1", "massart")

# %%
df = pd.DataFrame.from_dict(rows, orient='columns')
df.head()
# Out:
#    index      label       pred  epsilon  p_safe_attack  d_safe_attack  \
# 0      0  21.551691  21.526541     0.01       1.000000          False
# 1      0  21.551691  21.526541     0.01       0.807143          False
# 2      1  27.039705  27.060947     0.01       1.000000          False
# 3      1  27.039705  27.060947     0.01       1.000000          False
# 4      2  42.760319  42.766071     0.01       1.000000          False
#
#    p_safe_bounds  d_safe_bounds  beps  bdelt  balpha  iterations_attack  \
# 0       1.000000          False  0.05    0.1    0.05               57.0
# 1       0.807143          False  0.05    0.1    0.05               57.0
# 2       1.000000          False  0.05    0.1    0.05               57.0
# 3       1.000000          False  0.05    0.1    0.05               57.0
# 4       1.000000          False  0.05    0.1    0.05               57.0
#
#    iterations_bounds  veri_time  attk_time Dataset    Bound  Method
# 0              140.0   0.536971   5.102456  boston  massart  Attack
# 1              140.0   0.536971   5.102456  boston  massart    Cert
# 2               57.0   0.336837   6.166109  boston  massart  Attack
# 3               57.0   0.336837   6.166109  boston  massart    Cert
# 4               55.0   0.271586   5.922242  boston  massart  Attack

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5), dpi=100)

sns.set_theme(style="whitegrid")
sns.set_palette('turbo')

sns.violinplot(data=df, x="Dataset", y="p_safe_attack", hue="Method",
               split=True, inner="quart", linewidth=1)

sns.stripplot(x="Dataset", y="p_safe_attack", hue="Method", size=3,
                 data=df, dodge=True, edgecolor='white', linewidth=0.5, jitter=0.2)
  
plt.title("Probabilistic Safety - UCI Datasets")
plt.ylabel("Value of Probabilistic Safety")
plt.xlabel("Dataset")

sns.despine(left=True)
plt.legend(bbox_to_anchor=(1.2,0.5), loc="center right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9af1df99c89c> in <module>
#       8 sns.set_palette('turbo')
#       9
# ---> 10 sns.violinplot(data=df, x="Dataset", y="p_safe_attack", hue="Method",
#      11                split=True, linewidth=1)
#      12
#
# NameError: name 'df' is not defined
